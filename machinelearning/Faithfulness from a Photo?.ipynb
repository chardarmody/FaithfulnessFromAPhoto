# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# read data as data
data = pd.read_csv('FaithfulFaces.csv', index_col=[0])

data.describe()
# Out:
#        SexDimorph     Attract     Cheater       Trust    Faithful
# count  170.000000  170.000000  170.000000  170.000000  170.000000
# mean     4.162171    2.992700    0.294118    4.323206    5.140376
# std      0.978791    0.868053    0.456991    0.790906    0.957460
# min      2.000000    1.250000    0.000000    2.353000    2.765000
# 25%      3.417000    2.417000    0.000000    3.824000    4.426750
# 50%      4.083000    2.958500    0.000000    4.235000    5.235000
# 75%      4.833000    3.500000    1.000000    4.882000    5.824000
# max      6.250000    6.333000    1.000000    6.471000    7.176000

# %%
data = pd.read_csv('FaithfulFaces.csv')

# %%
data.describe()
# Out:
#        Unnamed: 0  SexDimorph     Attract     Cheater       Trust    Faithful
# count  170.000000  170.000000  170.000000  170.000000  170.000000  170.000000
# mean    85.500000    4.162171    2.992700    0.294118    4.323206    5.140376
# std     49.218899    0.978791    0.868053    0.456991    0.790906    0.957460
# min      1.000000    2.000000    1.250000    0.000000    2.353000    2.765000
# 25%     43.250000    3.417000    2.417000    0.000000    3.824000    4.426750
# 50%     85.500000    4.083000    2.958500    0.000000    4.235000    5.235000
# 75%    127.750000    4.833000    3.500000    1.000000    4.882000    5.824000
# max    170.000000    6.250000    6.333000    1.000000    6.471000    7.176000

# %%
data.head()
# Out:
#    Unnamed: 0  SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 0           1       4.900    2.000        1  4.118     6.294       F        M
# 1           2       2.583    2.083        1  4.000     6.588       F        M
# 2           3       4.300    2.667        1  3.941     5.824       F        M
# 3           4       4.083    2.917        0  4.118     5.412       F        M
# 4           5       4.500    3.500        0  3.235     4.000       F        M

# %%
data = pd.read_csv('FaithfulFaces.csv', index_col=[0])

# %%
data.describe()
# Out:
#        SexDimorph     Attract     Cheater       Trust    Faithful
# count  170.000000  170.000000  170.000000  170.000000  170.000000
# mean     4.162171    2.992700    0.294118    4.323206    5.140376
# std      0.978791    0.868053    0.456991    0.790906    0.957460
# min      2.000000    1.250000    0.000000    2.353000    2.765000
# 25%      3.417000    2.417000    0.000000    3.824000    4.426750
# 50%      4.083000    2.958500    0.000000    4.235000    5.235000
# 75%      4.833000    3.500000    1.000000    4.882000    5.824000
# max      6.250000    6.333000    1.000000    6.471000    7.176000

# %%
corr = data.corr()
sns.heatmap(corr, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
sns.relplot(x="Attract", y="SexDimorph", hue="Cheater", data=data);

# %%
x_cheater = data.replace({'Cheater' : {1: 'yes', 0: 'no'}})
y_cheater = data.replace({'Cheater' : {1: 'yes', 0: 'no'}})
sns.relplot(x="Attract", y="SexDimorph", hue='x_cheater' 'y_cheater', data=data);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f712e04fd23c> in <module>
#       1 x_cheater = data.replace({'Cheater' : {1: 'yes', 0: 'no'}})
#       2 y_cheater = data.replace({'Cheater' : {1: 'yes', 0: 'no'}})
# ----> 3 sns.relplot(x="Attract", y="SexDimorph", hue='x_cheater' 'y_cheater', data=data);
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     931
#     932     # Use the full dataset to map the semantics
# --> 933     p = plotter(
#     934         data=data,
#     935         variables=plotter.get_semantics(locals()),
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     578         )
#     579
# --> 580         super().__init__(data=data, variables=variables)
#     581
#     582         self.alpha = alpha
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     885                     # We don't know what this name means
#     886                     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 887                     raise ValueError(err)
#     888
#     889             else:
#
# ValueError: Could not interpret value `x_cheatery_cheater` for parameter `hue`

# %%
data.replace({'Cheater' : {1: 'yes', 0: 'no'}})

sns.relplot(x="Attract", y="SexDimorph", hue="Cheater", data=data);

# %%
data.replace({'Cheater' : {1: 'yes', 0: 'no'}}).groupby('Cheater').size().reset_index(name='Counts')['Cheater']

sns.relplot(x="Attract", y="SexDimorph", hue="Cheater", data=data);

# %%
data['Cheater'] = data['Cheater'].map({0 : 'No', 1 : 'Yes'})

# %%
sns.relplot(x="Attract", y="SexDimorph", hue="Cheater", data=data);

# %%
data['Cheater'] = data['Cheater'].map({'No' : 'Yes', 'Yes' : 'No'})
sns.relplot(x="Attract", y="SexDimorph", hue="Cheater", data=data);

# %%
data_ml = data.copy()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
data_ml = pd.get_dummies(data_ml, columns=['Cheater', 'FaceSex', 'RaterSex'], drop_first=true)
data_ml.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3c3d2dc36634> in <module>
# ----> 1 data_ml = pd.get_dummies(data_ml, columns=['Cheater', 'FaceSex', 'RaterSex'], drop_first=true)
#       2 data_ml.head()
#
# NameError: name 'true' is not defined

# %%
data_ml = pd.get_dummies(data_ml, columns=['Cheater', 'FaceSex', 'RaterSex'], drop_first=True)

# %%
data_ml.head()
# Out:
#    SexDimorph  Attract  Trust  Faithful  Cheater_Yes  FaceSex_M  RaterSex_M
# 1       4.900    2.000  4.118     6.294            0          0           1
# 2       2.583    2.083  4.000     6.588            0          0           1
# 3       4.300    2.667  3.941     5.824            0          0           1
# 4       4.083    2.917  4.118     5.412            1          0           1
# 5       4.500    3.500  3.235     4.000            1          0           1

# %%
data_ml.head(10)
# Out:
#     SexDimorph  Attract  Trust  Faithful  Cheater_Yes  FaceSex_M  RaterSex_M
# 1        4.900    2.000  4.118     6.294            0          0           1
# 2        2.583    2.083  4.000     6.588            0          0           1
# 3        4.300    2.667  3.941     5.824            0          0           1
# 4        4.083    2.917  4.118     5.412            1          0           1
# 5        4.500    3.500  3.235     4.000            1          0           1
# 6        2.000    1.833  4.647     6.647            1          0           1
# 7        2.273    1.417  3.588     6.235            0          0           1
# 8        3.917    2.417  4.118     4.600            0          0           1
# 9        5.833    4.417  3.235     3.550            1          0           1
# 10       3.727    2.167  4.471     6.588            1          0           1

# %%
data_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 1 to 170
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SexDimorph   170 non-null    float64
#  1   Attract      170 non-null    float64
#  2   Trust        170 non-null    float64
#  3   Faithful     170 non-null    float64
#  4   Cheater_Yes  170 non-null    uint8
#  5   FaceSex_M    170 non-null    uint8
#  6   RaterSex_M   170 non-null    uint8
# dtypes: float64(4), uint8(3)
# memory usage: 7.1 KB

# %%
corr = data_ml.corr()
f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
data_ml=data_ml.rename(columns={"Cheater_Yes":"Cheater"})

# %%
data_ml.head()
# Out:
#    SexDimorph  Attract  Trust  Faithful  Cheater  FaceSex_M  RaterSex_M
# 1       4.900    2.000  4.118     6.294        0          0           1
# 2       2.583    2.083  4.000     6.588        0          0           1
# 3       4.300    2.667  3.941     5.824        0          0           1
# 4       4.083    2.917  4.118     5.412        1          0           1
# 5       4.500    3.500  3.235     4.000        1          0           1

# %%
data_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 1 to 170
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SexDimorph  170 non-null    float64
#  1   Attract     170 non-null    float64
#  2   Trust       170 non-null    float64
#  3   Faithful    170 non-null    float64
#  4   Cheater     170 non-null    uint8
#  5   FaceSex_M   170 non-null    uint8
#  6   RaterSex_M  170 non-null    uint8
# dtypes: float64(4), uint8(3)
# memory usage: 7.1 KB

# %%
corr = data_ml.corr()
f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()


scaler.fit(data_ml.drop('Attract',axis=1))
scaled_features = scaler.transform(data_ml.drop('Attract',axis=1))
data_ml_sc = pd.DataFrame(scaled_features, columns=data_ml.columns[:-1])

# %%
print(data.Attract.sum()/data.Attract.count())
# Out:
# 2.9927000000000006

# %%
print(data.Cheater.sum()/data.Cheater.count())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-c7696c0300c3> in <module>
# ----> 1 print(data.Cheater.sum()/data.Cheater.count())
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
data=pd.read_csv('FaithfulFaces.csv')
data.head()
# Out:
#    Unnamed: 0  SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 0           1       4.900    2.000        1  4.118     6.294       F        M
# 1           2       2.583    2.083        1  4.000     6.588       F        M
# 2           3       4.300    2.667        1  3.941     5.824       F        M
# 3           4       4.083    2.917        0  4.118     5.412       F        M
# 4           5       4.500    3.500        0  3.235     4.000       F        M

# %%
data=pd.read_csv('FaithfulFaces.csv', index_col=[0])
data.head()
# Out:
#    SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 1       4.900    2.000        1  4.118     6.294       F        M
# 2       2.583    2.083        1  4.000     6.588       F        M
# 3       4.300    2.667        1  3.941     5.824       F        M
# 4       4.083    2.917        0  4.118     5.412       F        M
# 5       4.500    3.500        0  3.235     4.000       F        M

# %%
y=data.Attract
x=data.drop('Attract',axis=1)

# %%
data_train,data_test,data_train,data_test=train_test_split(x,y,test_size=0.2)
data_train.head()
# Out:
# 148    2.417
# 99     3.417
# 113    2.167
# 156    2.083
# 141    1.667
# Name: Attract, dtype: float64

# %%
data_test.head()
# Out:
# 157    2.417
# 169    2.333
# 91     3.417
# 98     3.083
# 82     2.167
# Name: Attract, dtype: float64

# %%
data_train.shape
# Out:
# (136,)

# %%
data_test_ml = data_test.copy()
data_train_ml = data_train.copy()

# %%
data_train_ml.head()
# Out:
# 148    2.417
# 99     3.417
# 113    2.167
# 156    2.083
# 141    1.667
# Name: Attract, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
xTrain.head()
# Out:
#      SexDimorph  Cheater  Trust  Faithful FaceSex RaterSex
# 120       4.583        1  4.353     3.882       M        F
# 93        3.167        0  3.824     5.412       M        F
# 99        4.083        0  3.824     5.176       M        F
# 153       3.667        0  4.118     4.882       M        F
# 156       3.167        0  3.529     5.059       M        F

# %%
data_train_ml = x,yTrain.copy()

# %%
data_train_ml.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-aa76c7dac0ed> in <module>
# ----> 1 data_train_ml.head()
#
# AttributeError: 'tuple' object has no attribute 'head'

# %%
data_train_ml = xTrain.copy()

# %%
data_train_ml.head()
# Out:
#      SexDimorph  Cheater  Trust  Faithful FaceSex RaterSex
# 120       4.583        1  4.353     3.882       M        F
# 93        3.167        0  3.824     5.412       M        F
# 99        4.083        0  3.824     5.176       M        F
# 153       3.667        0  4.118     4.882       M        F
# 156       3.167        0  3.529     5.059       M        F

# %%
data_test_ml = xTest.copy()
data_test_ml.head()
# Out:
#      SexDimorph  Cheater  Trust  Faithful FaceSex RaterSex
# 134       4.750        0  4.706     5.059       M        F
# 137       4.500        0  6.176     5.882       M        F
# 169       4.750        0  3.000     3.824       M        F
# 55        4.700        0  5.824     5.353       F        M
# 57        3.833        0  3.588     4.294       F        M

# %%
data_train_ml.describe()
# Out:
#        SexDimorph     Cheater       Trust    Faithful
# count  136.000000  136.000000  136.000000  136.000000
# mean     4.116191    0.301471    4.312324    5.138037
# std      0.989880    0.460593    0.773471    0.922392
# min      2.167000    0.000000    2.353000    3.059000
# 25%      3.333000    0.000000    3.824000    4.471000
# 50%      4.000000    0.000000    4.176000    5.235000
# 75%      4.849750    1.000000    4.941000    5.779750
# max      6.250000    1.000000    6.471000    7.176000

# %%
data_test_ml.describe()
# Out:
#        SexDimorph    Cheater      Trust   Faithful
# count   34.000000  34.000000  34.000000  34.000000
# mean     4.346088   0.264706   4.366735   5.149735
# std      0.924228   0.447811   0.868118   1.101853
# min      2.000000   0.000000   2.647000   2.765000
# 25%      3.854000   0.000000   3.896750   4.323500
# 50%      4.458500   0.000000   4.412000   5.235500
# 75%      4.812250   0.750000   4.750250   6.117250
# max      6.083000   1.000000   6.176000   6.706000

# %%
data_train_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 120 to 48
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SexDimorph  136 non-null    float64
#  1   Cheater     136 non-null    int64
#  2   Trust       136 non-null    float64
#  3   Faithful    136 non-null    float64
#  4   FaceSex     136 non-null    object
#  5   RaterSex    136 non-null    object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 7.4+ KB

# %%
data_train_ml = pd.get_dummies(data_train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
data_train_ml.drop(['SexDimorph','Cheater ','Trust ', 'Faithful'],axis=1,inplace=True)
data_train_ml.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-d39a255fb0db> in <module>
#       1 data_train_ml = pd.get_dummies(data_train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
# ----> 2 data_train_ml.drop(['SexDimorph','Cheater ','Trust ', 'Faithful'],axis=1,inplace=True)
#       3 data_train_ml.dropna(inplace=True)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Cheater ' 'Trust '] not found in axis"

# %%
data_train_ml = pd.get_dummies(data_train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
data_train_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
data_train_ml.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-dec3dc48ac9a> in <module>
# ----> 1 data_train_ml = pd.get_dummies(data_train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
#       2 data_train_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
#       3 data_train_ml.dropna(inplace=True)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     841             raise TypeError("Input must be a list-like for parameter `columns`")
#     842         else:
# --> 843             data_to_encode = data[columns]
#     844
#     845         # validate prefixes and separator to avoid silently dropping cols
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['FaceSex', 'RaterSex'], dtype='object')] are in the [columns]"

# %%
data_train_ml.head()
# Out:
#      SexDimorph  Cheater  Trust  Faithful  FaceSex_M  RaterSex_M
# 120       4.583        1  4.353     3.882          1           0
# 93        3.167        0  3.824     5.412          1           0
# 99        4.083        0  3.824     5.176          1           0
# 153       3.667        0  4.118     4.882          1           0
# 156       3.167        0  3.529     5.059          1           0

# %%
data_train_ml = pd.get_dummies(data_train_ml, columns=['FaceSex_M', 'RaterSex_M', 'FaceSex_F', 'RaterSex_F'], drop_first=True)
data_train_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
data_train_ml.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-c94f13fb3cd6> in <module>
# ----> 1 data_train_ml = pd.get_dummies(data_train_ml, columns=['FaceSex_M', 'RaterSex_M', 'FaceSex_F', 'RaterSex_F'], drop_first=True)
#       2 data_train_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
#       3 data_train_ml.dropna(inplace=True)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     841             raise TypeError("Input must be a list-like for parameter `columns`")
#     842         else:
# --> 843             data_to_encode = data[columns]
#     844
#     845         # validate prefixes and separator to avoid silently dropping cols
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['RaterSex_F', 'FaceSex_F'] not in index"

# %%
data_train_ml = pd.get_dummies(data_train_ml, columns=['FaceSex_M', 'RaterSex_M'], drop_first=True)
data_train_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
data_train_ml.dropna(inplace=True)

# %%
sex_dimorph = df_test_ml['SexDimorph']
data_test_ml = pd.get_dummies(data_test_ml, columns=['FaceSex_M', 'RaterSex_M'], drop_first=True)
data_test_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-f1198222b55e> in <module>
# ----> 1 sex_dimorph = df_test_ml['SexDimorph']
#       2 data_test_ml = pd.get_dummies(data_test_ml, columns=['FaceSex_M', 'RaterSex_M'], drop_first=True)
#       3 data_test_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
#
# NameError: name 'df_test_ml' is not defined

# %%
sex_dimorph = data_test_ml['SexDimorph']
data_test_ml = pd.get_dummies(data_test_ml, columns=['FaceSex_M', 'RaterSex_M'], drop_first=True)
data_test_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-c75b992ee746> in <module>
#       1 sex_dimorph = data_test_ml['SexDimorph']
# ----> 2 data_test_ml = pd.get_dummies(data_test_ml, columns=['FaceSex_M', 'RaterSex_M'], drop_first=True)
#       3 data_test_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     841             raise TypeError("Input must be a list-like for parameter `columns`")
#     842         else:
# --> 843             data_to_encode = data[columns]
#     844
#     845         # validate prefixes and separator to avoid silently dropping cols
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['FaceSex_M', 'RaterSex_M'], dtype='object')] are in the [columns]"

# %%
sex_dimorph = data_test_ml['SexDimorph']
data_test_ml = pd.get_dummies(data_test_ml, columns=['FaceSex_F', 'RaterSex_F'], drop_first=True)
data_test_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-dfe137332eee> in <module>
#       1 sex_dimorph = data_test_ml['SexDimorph']
# ----> 2 data_test_ml = pd.get_dummies(data_test_ml, columns=['FaceSex_F', 'RaterSex_F'], drop_first=True)
#       3 data_test_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     841             raise TypeError("Input must be a list-like for parameter `columns`")
#     842         else:
# --> 843             data_to_encode = data[columns]
#     844
#     845         # validate prefixes and separator to avoid silently dropping cols
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['FaceSex_F', 'RaterSex_F'], dtype='object')] are in the [columns]"

# %%
data_test_ml.head()
# Out:
#      SexDimorph  Cheater  Trust  Faithful FaceSex RaterSex
# 134       4.750        0  4.706     5.059       M        F
# 137       4.500        0  6.176     5.882       M        F
# 169       4.750        0  3.000     3.824       M        F
# 55        4.700        0  5.824     5.353       F        M
# 57        3.833        0  3.588     4.294       F        M

# %%
data_test_ml.info
# Out:
# <bound method DataFrame.info of      SexDimorph  Cheater  Trust  Faithful FaceSex RaterSex
# 134       4.750        0  4.706     5.059       M        F
# 137       4.500        0  6.176     5.882       M        F
# 169       4.750        0  3.000     3.824       M        F
# 55        4.700        0  5.824     5.353       F        M
# 57        3.833        0  3.588     4.294       F        M
# 145       4.250        0  4.294     5.000       M        F
# 8         3.917        1  4.118     4.600       F        M
# 97        5.083        1  5.412     4.412       M        F
# 122       3.917        1  4.765     4.824       M        F
# 98        5.583        0  4.471     5.529       M        F
# 142       4.417        0  4.235     5.882       M        F
# 6         2.000        0  4.647     6.647       F        M
# 84        4.833        1  2.647     2.765       M        F
# 110       4.917        0  4.765     5.706       M        F
# 56        3.818        0  4.647     6.294       F        M
# 19        3.727        0  3.882     5.353       F        M
# 62        4.083        0  4.529     5.059       F        M
# 102       5.500        0  3.294     3.176       M        F
# 61        4.500        0  5.529     6.294       F        M
# 64        5.167        0  5.824     6.176       F        M
# 154       4.000        0  3.941     5.706       M        F
# 5         4.500        0  3.235     4.000       F        M
# 107       5.750        0  4.353     4.000       M        F
# 162       2.417        0  4.471     6.235       M        F
# 109       6.083        1  3.176     3.294       M        F
# 38        4.500        1  4.647     4.824       F        M
# 67        3.417        1  4.176     5.941       F        M
# 158       4.750        1  3.353     5.118       M        F
# 46        3.545        0  4.588     6.412       F        M
# 27        3.500        0  5.118     6.471       F        M
# 34        4.083        0  5.529     6.529       F        M
# 126       4.417        1  4.118     4.176       M        F
# 45        2.727        0  4.176     6.706       F        M
# 9         5.833        0  3.235     3.550       F        M>

# %%
sex_dimorph = data_test_ml['SexDimorph']
data_test_ml = pd.get_dummies(data_test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
data_test_ml.drop(['SexDimorph','Cheater', 'Trust', 'Faithful'],axis=1,inplace=True)

# %%
data_train_ml.head(10)
# Out:
#      FaceSex_M_1  RaterSex_M_1
# 120            1             0
# 93             1             0
# 99             1             0
# 153            1             0
# 156            1             0
# 25             0             1
# 31             0             1
# 114            1             0
# 52             0             1
# 111            1             0

# %%
data_train_ml.head
# Out:
# <bound method NDFrame.head of      FaceSex_M_1  RaterSex_M_1
# 120            1             0
# 93             1             0
# 99             1             0
# 153            1             0
# 156            1             0
# ..           ...           ...
# 10             0             1
# 104            1             0
# 68             0             1
# 118            1             0
# 48             0             1
#
# [136 rows x 2 columns]>

# %%
data_train_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 120 to 48
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FaceSex_M_1   136 non-null    uint8
#  1   RaterSex_M_1  136 non-null    uint8
# dtypes: uint8(2)
# memory usage: 1.3 KB

# %%
data_test_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 134 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FaceSex_M   34 non-null     uint8
#  1   RaterSex_M  34 non-null     uint8
# dtypes: uint8(2)
# memory usage: 340.0 bytes

# %%
corr = df_train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-6e3b7297c39a> in <module>
# ----> 1 corr = df_train_ml.corr()
#       2
#       3 f,ax = plt.subplots(figsize=(9,6))
#       4 sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
#       5 plt.show()
#
# NameError: name 'df_train_ml' is not defined

# %%
corr = data_train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
data.head()
# Out:
#    SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 1       4.900    2.000        1  4.118     6.294       F        M
# 2       2.583    2.083        1  4.000     6.588       F        M
# 3       4.300    2.667        1  3.941     5.824       F        M
# 4       4.083    2.917        0  4.118     5.412       F        M
# 5       4.500    3.500        0  3.235     4.000       F        M

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index_col=[0]))
data['split'] = np.random.randn(data.shape[0], 1)

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]
# Out:
#   File "<ipython-input-67-1f3b1083e598>", line 4
#     data = pd.read_csv('FaithfulFaces.csv', index_col=[0]))
#                                                           ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index_col=[0])
data['split'] = np.random.randn(data.shape[0], 1)

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]

# %%
train.head()
# Out:
#    SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex     split
# 4       4.083    2.917        0  4.118     5.412       F        M  0.834896
# 5       4.500    3.500        0  3.235     4.000       F        M -1.054711
# 6       2.000    1.833        0  4.647     6.647       F        M  0.755963
# 7       2.273    1.417        1  3.588     6.235       F        M -1.548958
# 8       3.917    2.417        1  4.118     4.600       F        M  0.212845

# %%
test.head()
# Out:
#     SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex     split
# 1        4.900    2.000        1  4.118     6.294       F        M -1.566975
# 2        2.583    2.083        1  4.000     6.588       F        M  1.246791
# 3        4.300    2.667        1  3.941     5.824       F        M  0.658767
# 9        5.833    4.417        0  3.235     3.550       F        M -0.351195
# 10       3.727    2.167        0  4.471     6.588       F        M -0.110412

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116 entries, 4 to 168
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SexDimorph  116 non-null    float64
#  1   Attract     116 non-null    float64
#  2   Cheater     116 non-null    int64
#  3   Trust       116 non-null    float64
#  4   Faithful    116 non-null    float64
#  5   FaceSex     116 non-null    object
#  6   RaterSex    116 non-null    object
#  7   split       116 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 8.2+ KB

# %%
train_ml = pd.get_dummies(train_ml, columns=['Cheater', 'FaceSex', 'RaterSex'], drop_first=True)
train_ml.drop(['SexDimorph','Attract','Trust', 'Faithful'],axis=1,inplace=True)
train_ml.dropna(inplace=True)

# %%
test_ml = pd.get_dummies(test_ml, columns=['Cheater', 'FaceSex', 'RaterSex'], drop_first=True)
test_ml.drop(['SexDimorph','Attract','Trust', 'Faithful'],axis=1,inplace=True)
test_ml.dropna(inplace=True)

# %%
train_ml.head()
# Out:
#       split  Cheater_1  FaceSex_M  RaterSex_M
# 4  0.834896          0          0           1
# 5 -1.054711          0          0           1
# 6  0.755963          0          0           1
# 7 -1.548958          1          0           1
# 8  0.212845          1          0           1

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index=False)
data['split'] = np.random.randn(data.shape[0], 1)

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-5ee4f85afa72> in <module>
#       2 import numpy as np
#       3
# ----> 4 data = pd.read_csv('FaithfulFaces.csv', index=False)
#       5 data['split'] = np.random.randn(data.shape[0], 1)
#       6
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index_col=False)
data['split'] = np.random.randn(data.shape[0], 1)

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112 entries, 0 to 169
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  112 non-null    int64
#  1   SexDimorph  112 non-null    float64
#  2   Attract     112 non-null    float64
#  3   Cheater     112 non-null    int64
#  4   Trust       112 non-null    float64
#  5   Faithful    112 non-null    float64
#  6   FaceSex     112 non-null    object
#  7   RaterSex    112 non-null    object
#  8   split       112 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 8.8+ KB

# %%
train.head()
# Out:
#    Unnamed: 0  SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex  \
# 0           1       4.900    2.000        1  4.118     6.294       F        M
# 1           2       2.583    2.083        1  4.000     6.588       F        M
# 3           4       4.083    2.917        0  4.118     5.412       F        M
# 5           6       2.000    1.833        0  4.647     6.647       F        M
# 6           7       2.273    1.417        1  3.588     6.235       F        M
#
#       split
# 0 -0.060934
# 1 -0.421499
# 3  0.308705
# 5 -0.976055
# 6 -0.018944

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index=False)
data['split'] = np.random.randn(data.shape[0], 1)

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-5ee4f85afa72> in <module>
#       2 import numpy as np
#       3
# ----> 4 data = pd.read_csv('FaithfulFaces.csv', index=False)
#       5 data['split'] = np.random.randn(data.shape[0], 1)
#       6
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index_col=[0]))
data = np.random.randn(data.shape[0], 1)

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]
# Out:
#   File "<ipython-input-81-87808e55c4f2>", line 4
#     data = pd.read_csv('FaithfulFaces.csv', index_col=[0]))
#                                                           ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index_col=[0])
data = np.random.randn(data.shape[0], 1)

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]

# %%
train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-3b77fa18a747> in <module>
# ----> 1 train.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index_col=[0])
rng = RandomState()

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-11a005bff766> in <module>
#       3
#       4 data = pd.read_csv('FaithfulFaces.csv', index_col=[0])
# ----> 5 rng = RandomState()
#       6
#       7 msk = np.random.rand(len(data)) <= 0.7
#
# NameError: name 'RandomState' is not defined

# %%
from numpy.random import RandomState
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index_col=[0])
rng = RandomState()

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]

# %%
train.head()
# Out:
#    SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 1       4.900    2.000        1  4.118     6.294       F        M
# 2       2.583    2.083        1  4.000     6.588       F        M
# 3       4.300    2.667        1  3.941     5.824       F        M
# 4       4.083    2.917        0  4.118     5.412       F        M
# 5       4.500    3.500        0  3.235     4.000       F        M

# %%
test.head()
# Out:
#     SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 8        3.917    2.417        1  4.118     4.600       F        M
# 17       3.909    3.000        0  4.941     5.824       F        M
# 19       3.727    2.333        0  3.882     5.353       F        M
# 20       3.833    2.667        0  5.000     6.059       F        M
# 24       3.167    2.750        1  4.941     5.765       F        M

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
train_ml.head()
# Out:
#    SexDimorph  Attract  Cheater  Trust  Faithful  FaceSex_M  RaterSex_M
# 1       4.900    2.000        1  4.118     6.294          0           1
# 2       2.583    2.083        1  4.000     6.588          0           1
# 3       4.300    2.667        1  3.941     5.824          0           1
# 4       4.083    2.917        0  4.118     5.412          0           1
# 5       4.500    3.500        0  3.235     4.000          0           1

# %%
test_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-44418066ea4b> in <module>
# ----> 1 test_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     841             raise TypeError("Input must be a list-like for parameter `columns`")
#     842         else:
# --> 843             data_to_encode = data[columns]
#     844
#     845         # validate prefixes and separator to avoid silently dropping cols
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['FaceSex', 'RaterSex'], dtype='object')] are in the [columns]"

# %%
test_ml.head()
# Out:
#     SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 8        3.917    2.417        1  4.118     4.600       F        M
# 17       3.909    3.000        0  4.941     5.824       F        M
# 19       3.727    2.333        0  3.882     5.353       F        M
# 20       3.833    2.667        0  5.000     6.059       F        M
# 24       3.167    2.750        1  4.941     5.765       F        M

# %%
test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
test_ml.head()
# Out:
#     SexDimorph  Attract  Cheater  Trust  Faithful  FaceSex_M  RaterSex_M
# 8        3.917    2.417        1  4.118     4.600          0           1
# 17       3.909    3.000        0  4.941     5.824          0           1
# 19       3.727    2.333        0  3.882     5.353          0           1
# 20       3.833    2.667        0  5.000     6.059          0           1
# 24       3.167    2.750        1  4.941     5.765          0           1

# %%
corr = df_train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-6e3b7297c39a> in <module>
# ----> 1 corr = df_train_ml.corr()
#       2
#       3 f,ax = plt.subplots(figsize=(9,6))
#       4 sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
#       5 plt.show()
#
# NameError: name 'df_train_ml' is not defined

# %%
corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# for train_ml
scaler.fit(train_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(train_ml.drop('Cheater',axis=1))
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns[:-1])

# for test_ml
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-60896f0568e4> in <module>
#      10 test_ml.fillna(test_ml.mean(), inplace=True)
#      11 # scaler.fit(test_ml)
# ---> 12 scaled_features = scaler.transform(test_ml)
#      13 test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     789
#     790         copy = copy if copy is not None else self.copy
# --> 791         X = self._validate_data(X, reset=False,
#     792                                 accept_sparse='csr', copy=copy,
#     793                                 estimator=self, dtype=FLOAT_DTYPES,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     434
#     435         if check_params.get('ensure_2d', True):
# --> 436             self._check_n_features(X, reset=reset)
#     437
#     438         return out
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     375                 )
#     376             if n_features != self.n_features_in_:
# --> 377                 raise ValueError(
#     378                     'X has {} features, but this {} is expecting {} features '
#     379                     'as input.'.format(n_features, self.__class__.__name__,
#
# ValueError: X has 7 features, but this StandardScaler is expecting 6 features as input.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml.drop('Cheater',axis=1), train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

# %%
# unscaled
X_train_all = train_ml.drop('Cheater',axis=1)
y_train_all = train_ml['Cheater']
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml['Cheater']
X_test_all_sc = test_ml_sc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-9833a582fdfb> in <module>
#       7 X_train_all_sc = train_ml_sc
#       8 y_train_all_sc = train_ml['Cheater']
# ----> 9 X_test_all_sc = test_ml_sc
#
# NameError: name 'test_ml_sc' is not defined

# %%
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-b43baa8a5aeb> in <module>
#       1 test_ml.fillna(test_ml.mean(), inplace=True)
#       2 # scaler.fit(test_ml)
# ----> 3 scaled_features = scaler.transform(test_ml)
#       4 test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     789
#     790         copy = copy if copy is not None else self.copy
# --> 791         X = self._validate_data(X, reset=False,
#     792                                 accept_sparse='csr', copy=copy,
#     793                                 estimator=self, dtype=FLOAT_DTYPES,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     434
#     435         if check_params.get('ensure_2d', True):
# --> 436             self._check_n_features(X, reset=reset)
#     437
#     438         return out
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     375                 )
#     376             if n_features != self.n_features_in_:
# --> 377                 raise ValueError(
#     378                     'X has {} features, but this {} is expecting {} features '
#     379                     'as input.'.format(n_features, self.__class__.__name__,
#
# ValueError: X has 7 features, but this StandardScaler is expecting 6 features as input.

# %%
scaler.fit(train_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(train_ml.drop('Cheater',axis=1))
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns[:-1])

# %%
scaler.fit(test_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(test_ml.drop('Cheater',axis=1))
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns[:-1])

# %%
# unscaled
X_train_all = train_ml.drop('Cheater',axis=1)
y_train_all = train_ml['Cheater']
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml['Cheater']
X_test_all_sc = test_ml_sc

# %%
X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")
# Out:
# *

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[23  0]
#  [13  0]]
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        23
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.64        36
#    macro avg       0.32      0.50      0.39        36
# weighted avg       0.41      0.64      0.50        36
#
# 0.6388888888888888
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-6dcffa98c8ca> in <module>
#       1 logreg.fit(X_train_all, y_train_all)
# ----> 2 pred_all_logreg = logreg.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     305             Predicted class label per sample.
#     306         """
# --> 307         scores = self.decision_function(X)
#     308         if len(scores.shape) == 1:
#     309             indices = (scores > 0).astype(np.int)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
#     287                              % (X.shape[1], n_features))
#     288
#
# ValueError: X has 7 features per sample; expecting 6

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)
sub_logreg = pd.DataFrame()
sub_logreg['SexDimorph'] = df_test['SexDimorph']
sub_logreg['Cheater'] = pred_all_logreg
#sub_logmodel.to_csv('logmodel.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-b2e7046e8e1d> in <module>
#       1 logreg.fit(X_train_all, y_train_all)
# ----> 2 pred_all_logreg = logreg.predict(X_test_all)
#       3 sub_logreg = pd.DataFrame()
#       4 sub_logreg['SexDimorph'] = df_test['SexDimorph']
#       5 sub_logreg['Cheater'] = pred_all_logreg
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     305             Predicted class label per sample.
#     306         """
# --> 307         scores = self.decision_function(X)
#     308         if len(scores.shape) == 1:
#     309             indices = (scores > 0).astype(np.int)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
#     287                              % (X.shape[1], n_features))
#     288
#
# ValueError: X has 7 features per sample; expecting 6

# %%
From sklearn import *
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)
# Out:
#   File "<ipython-input-109-eeb5293bd8e0>", line 1
#     From sklearn import *
#          ^
# SyntaxError: invalid syntax

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
pred_gnb = gnb.predict(X_test)
print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[23  0]
#  [13  0]]
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        23
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.64        36
#    macro avg       0.32      0.50      0.39        36
# weighted avg       0.41      0.64      0.50        36
#
# 0.6388888888888888
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc,y_train_sc)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# [[23  0]
#  [13  0]]
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        23
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.64        36
#    macro avg       0.32      0.50      0.39        36
# weighted avg       0.41      0.64      0.50        36
#
# 0.6388888888888888
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
knn.fit(X_train_all, y_train_all)
pred_all_knn = knn.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-ab1f5bfa936e> in <module>
#       1 knn.fit(X_train_all, y_train_all)
# ----> 2 pred_all_knn = knn.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtree = dtree.predict(X_test)
print(classification_report(y_test,pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.74      0.67        23
#            1       0.25      0.15      0.19        13
#
#     accuracy                           0.53        36
#    macro avg       0.43      0.45      0.43        36
# weighted avg       0.48      0.53      0.49        36
#
# 0.5277777777777778

# %%
pred_dtree = dtree.predict(X_train)
print(classification_report(y_train,pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        59
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        81
#    macro avg       1.00      1.00      1.00        81
# weighted avg       1.00      1.00      1.00        81
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-b816efbbb65f> in <module>
#       1 pred_dtree = dtree.predict(X_train)
#       2 print(classification_report(y_train,pred_dtree))
# ----> 3 print(accuracy_score(y_test, pred_dtree))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     185
#     186     # Compute accuracy for each possible representation
# --> 187     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     188     check_consistent_length(y_true, y_pred, sample_weight)
#     189     if y_type.startswith('multilabel'):
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      79     y_pred : array or indicator matrix
#      80     """
# ---> 81     check_consistent_length(y_true, y_pred)
#      82     type_true = type_of_target(y_true)
#      83     type_pred = type_of_target(y_pred)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [36, 81]

# %%
pred_dtree = dtree.predict(X_train)
print(classification_report(y_train,pred_dtree))
print(accuracy_score(y_train, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        59
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        81
#    macro avg       1.00      1.00      1.00        81
# weighted avg       1.00      1.00      1.00        81
#
# 1.0

# %%
pred_dtree = dtree.predict(X_test)
print(classification_report(y_test,pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.74      0.67        23
#            1       0.25      0.15      0.19        13
#
#     accuracy                           0.53        36
#    macro avg       0.43      0.45      0.43        36
# weighted avg       0.48      0.53      0.49        36
#
# 0.5277777777777778

# %%
pred_dtree = dtree.predict(X_train)
print(classification_report(y_train,pred_dtree))
print(accuracy_score(y_train, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        59
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        81
#    macro avg       1.00      1.00      1.00        81
# weighted avg       1.00      1.00      1.00        81
#
# 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-38d1b467f853> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features=7, max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-2fff8cee4d10> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7, max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2.fit(X_train_all, y_train_all)
pred_all_dtree2 = dtree_2.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-00cea9fe2d7d> in <module>
# ----> 1 dtree_2.fit(X_train_all, y_train_all)
#       2 pred_all_dtree2 = dtree_2.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth=6, max_features=7)
rfc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-5e71d2903f15> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 rfc = RandomForestClassifier(max_depth=6, max_features=7)
# ----> 3 rfc.fit(X_train, y_train)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
pred_rfc = rfc.predict(X_test)
print(confusion_matrix(y_test, pred_rfc))
print(classification_report(y_test, pred_rfc))
print(accuracy_score(y_test, pred_rfc))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-125-4266af497852> in <module>
# ----> 1 pred_rfc = rfc.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_rfc))
#       3 print(classification_report(y_test, pred_rfc))
#       4 print(accuracy_score(y_test, pred_rfc))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# IndexError: list index out of range

# %%
rfc.fit(X_train_all, y_train_all)
pred_all_rfc = rfc.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-7b5854668aed> in <module>
# ----> 1 rfc.fit(X_train_all, y_train_all)
#       2 pred_all_rfc = rfc.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-38d1b467f853> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features="auto", max_depth="auto",  min_samples_split="auto")
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-31ca9303ae31> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features="auto", max_depth="auto",  min_samples_split="auto")
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     232             min_samples_split = self.min_samples_split
#     233         else:  # float
# --> 234             if not 0. < self.min_samples_split <= 1.:
#     235                 raise ValueError("min_samples_split must be an integer "
#     236                                  "greater than 1 or a float in (0.0, 1.0]; "
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-38d1b467f853> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features=0 , max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-5990adce9ddb> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=0 , max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features=n_features, max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-3880f5a9a958> in <module>
# ----> 1 dtree_2 = DecisionTreeClassifier(max_features=n_features, max_depth=6,  min_samples_split=8)
#       2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# NameError: name 'n_features' is not defined

# %%
from sklearn.svm import SVC
svc = SVC(gamma = 0.01, C = 100)#, probability=True)
svc.fit(X_train_sc, y_train_sc)
# Out:
# SVC(C=100, gamma=0.01)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth=6, max_features=7)
rfc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-5e71d2903f15> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 rfc = RandomForestClassifier(max_depth=6, max_features=7)
# ----> 3 rfc.fit(X_train, y_train)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
pred_rfc = rfc.predict(X_test)
print(confusion_matrix(y_test, pred_rfc))
print(classification_report(y_test, pred_rfc))
print(accuracy_score(y_test, pred_rfc))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-135-4266af497852> in <module>
# ----> 1 pred_rfc = rfc.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_rfc))
#       3 print(classification_report(y_test, pred_rfc))
#       4 print(accuracy_score(y_test, pred_rfc))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# IndexError: list index out of range

# %%
rfc.fit(X_train_all, y_train_all)
pred_all_rfc = rfc.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-7b5854668aed> in <module>
# ----> 1 rfc.fit(X_train_all, y_train_all)
#       2 pred_all_rfc = rfc.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
pred_rfc = rfc.predict(X_train)
print(confusion_matrix(y_train, pred_rfc))
print(classification_report(y_train, pred_rfc))
print(accuracy_score(y_train, pred_rfc))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-137-a49d88c4c203> in <module>
# ----> 1 pred_rfc = rfc.predict(X_train)
#       2 print(confusion_matrix(y_train, pred_rfc))
#       3 print(classification_report(y_train, pred_rfc))
#       4 print(accuracy_score(y_train, pred_rfc))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# IndexError: list index out of range

# %%
from sklearn.svm import SVC
svc = SVC(gamma = 0.01, C = 100)#, probability=True)
svc.fit(X_train_sc, y_train_sc)
# Out:
# SVC(C=100, gamma=0.01)

# %%
pred_svc = svc.predict(X_test_sc)
print(confusion_matrix(y_test_sc, pred_svc))
print(classification_report(y_test_sc, pred_svc))
print(accuracy_score(y_test_sc, pred_svc))
# Out:
# [[23  0]
#  [13  0]]
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        23
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.64        36
#    macro avg       0.32      0.50      0.39        36
# weighted avg       0.41      0.64      0.50        36
#
# 0.6388888888888888
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import cross_val_score

# %%
scores_svc = cross_val_score(svc, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_svc)
print(scores_svc.mean())
# Out:
# [0.66666667 0.66666667 0.66666667 0.66666667 0.66666667 0.75
#  0.75       0.72727273 0.72727273 0.72727273]
# 0.7015151515151515

# %%
scores_rfc = cross_val_score(rfc, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_rfc)
print(scores_rfc.mean())
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [nan nan nan nan nan nan nan nan nan nan]
# nan
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %%
scores_dtree_2 = cross_val_score(dtree_2, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_dtree_2)
print(scores_dtree_2.mean())
# Out:
# [nan nan nan nan nan nan nan nan nan nan]
# nan
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %%
from numpy.random import RandomState
import pandas as pd
import numpy as np

data = pd.read_csv('FaithfulFaces.csv', index_col=[0])
rng = RandomState()

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]

# %%
train.head()
# Out:
#    SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 1       4.900    2.000        1  4.118     6.294       F        M
# 4       4.083    2.917        0  4.118     5.412       F        M
# 6       2.000    1.833        0  4.647     6.647       F        M
# 7       2.273    1.417        1  3.588     6.235       F        M
# 8       3.917    2.417        1  4.118     4.600       F        M

# %%
test.head()
# Out:
#     SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 2        2.583    2.083        1  4.000     6.588       F        M
# 3        4.300    2.667        1  3.941     5.824       F        M
# 5        4.500    3.500        0  3.235     4.000       F        M
# 9        5.833    4.417        0  3.235     3.550       F        M
# 15       2.333    1.833        0  4.765     6.706       F        M

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 1 to 169
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SexDimorph  121 non-null    float64
#  1   Attract     121 non-null    float64
#  2   Cheater     121 non-null    int64
#  3   Trust       121 non-null    float64
#  4   Faithful    121 non-null    float64
#  5   FaceSex     121 non-null    object
#  6   RaterSex    121 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 7.6+ KB

# %%
train.describe()
# Out:
#        SexDimorph     Attract     Cheater       Trust    Faithful
# count  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     4.136686    3.016909    0.289256    4.369496    5.175636
# std      0.974236    0.896461    0.455302    0.786596    0.955191
# min      2.000000    1.250000    0.000000    2.353000    2.765000
# 25%      3.400000    2.417000    0.000000    3.824000    4.471000
# 50%      4.000000    2.917000    0.000000    4.235000    5.294000
# 75%      4.833000    3.500000    1.000000    4.941000    5.824000
# max      6.250000    6.333000    1.000000    6.471000    7.176000

# %%
train_ml.describe()
# Out:
#        SexDimorph     Attract     Cheater       Trust    Faithful
# count  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     4.136686    3.016909    0.289256    4.369496    5.175636
# std      0.974236    0.896461    0.455302    0.786596    0.955191
# min      2.000000    1.250000    0.000000    2.353000    2.765000
# 25%      3.400000    2.417000    0.000000    3.824000    4.471000
# 50%      4.000000    2.917000    0.000000    4.235000    5.294000
# 75%      4.833000    3.500000    1.000000    4.941000    5.824000
# max      6.250000    6.333000    1.000000    6.471000    7.176000

# %%
train_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 1 to 169
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SexDimorph  121 non-null    float64
#  1   Attract     121 non-null    float64
#  2   Cheater     121 non-null    int64
#  3   Trust       121 non-null    float64
#  4   Faithful    121 non-null    float64
#  5   FaceSex     121 non-null    object
#  6   RaterSex    121 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 7.6+ KB

# %%
train_ml = pd.get_dummies(train_ml, columns=['Cheater', 'FaceSex', 'RaterSex'], drop_first=True)

# %%
train_ml.describe()
# Out:
#        SexDimorph     Attract       Trust    Faithful   Cheater_1   FaceSex_M  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean     4.136686    3.016909    4.369496    5.175636    0.289256    0.479339
# std      0.974236    0.896461    0.786596    0.955191    0.455302    0.501650
# min      2.000000    1.250000    2.353000    2.765000    0.000000    0.000000
# 25%      3.400000    2.417000    3.824000    4.471000    0.000000    0.000000
# 50%      4.000000    2.917000    4.235000    5.294000    0.000000    0.000000
# 75%      4.833000    3.500000    4.941000    5.824000    1.000000    1.000000
# max      6.250000    6.333000    6.471000    7.176000    1.000000    1.000000
#
#        RaterSex_M
# count  121.000000
# mean     0.520661
# std      0.501650
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
train_ml = train.copy()

# %%
train_ml = pd.get_dummies(train_ml, columns=['Cheater', 'FaceSex', 'RaterSex'], drop_first=True)
test_ml = pd.get_dummies(test_ml, columns=['Cheater', 'FaceSex', 'RaterSex'], drop_first=True)

# %%
train_ml.head()
# Out:
#    SexDimorph  Attract  Trust  Faithful  Cheater_1  FaceSex_M  RaterSex_M
# 1       4.900    2.000  4.118     6.294          1          0           1
# 4       4.083    2.917  4.118     5.412          0          0           1
# 6       2.000    1.833  4.647     6.647          0          0           1
# 7       2.273    1.417  3.588     6.235          1          0           1
# 8       3.917    2.417  4.118     4.600          1          0           1

# %%
train_ml.head(10)
# Out:
#     SexDimorph  Attract  Trust  Faithful  Cheater_1  FaceSex_M  RaterSex_M
# 1        4.900    2.000  4.118     6.294          1          0           1
# 4        4.083    2.917  4.118     5.412          0          0           1
# 6        2.000    1.833  4.647     6.647          0          0           1
# 7        2.273    1.417  3.588     6.235          1          0           1
# 8        3.917    2.417  4.118     4.600          1          0           1
# 10       3.727    2.167  4.471     6.588          0          0           1
# 11       3.333    2.917  4.765     6.000          0          0           1
# 12       3.917    3.083  4.765     5.000          1          0           1
# 13       3.167    1.833  3.118     5.706          0          0           1
# 14       4.000    3.417  3.765     4.353          1          0           1

# %%
corr = df_train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6e3b7297c39a> in <module>
# ----> 1 corr = df_train_ml.corr()
#       2
#       3 f,ax = plt.subplots(figsize=(9,6))
#       4 sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
#       5 plt.show()
#
# NameError: name 'df_train_ml' is not defined

# %%
corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-23022cddfe9b> in <module>
#       1 corr = train_ml.corr()
#       2
# ----> 3 f,ax = plt.subplots(figsize=(9,6))
#       4 sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-61aee8395c40> in <module>
#       3
#       4 f,ax = plt.subplots(figsize=(9,6))
# ----> 5 sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
#       6 plt.show()
#
# NameError: name 'sns' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
corr = test_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# for train_ml
scaled_features = scaler.transform(train_ml)
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns)

# for test_ml
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-24-114b3dd75ebd> in <module>
#       3
#       4 # for train_ml
# ----> 5 scaled_features = scaler.transform(train_ml)
#       6 train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns)
#       7
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     786             Copy the input X or not.
#     787         """
# --> 788         check_is_fitted(self)
#     789
#     790         copy = copy if copy is not None else self.copy
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This StandardScaler instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# for train_ml
scaler.fit(train_ml)
scaled_features = scaler.transform(train_ml)
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns)

# for test_ml
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml), train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)
# Out:
#   File "<ipython-input-26-43922e316a7d>", line 2
#     X_train, X_test, y_train, y_test = train_test_split(train_ml), train_ml['Cheater'], test_size=0.30, random_state=101)
#                                                                                                                         ^
# SyntaxError: unmatched ')'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml, train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

# %%
# unscaled
X_train_all = train_ml
y_train_all = train_ml
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml
X_test_all_sc = test_ml_sc

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        11
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37
#
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        11
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37
#
# 1.0

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml.drop('Cheater',axis=1), train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# for train_ml
scaler.fit(train_ml)
scaled_features = scaler.transform(train_ml)
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns)

# for test_ml
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml, train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

# %%
#unscaled
X_train_all = train_ml.drop('Cheater',axis=1)
y_train_all = train_ml['Cheater']
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml['Cheater']
X_test_all_sc = test_ml_sc

# %%
X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")

*
# Out:
#   File "<ipython-input-40-25f55d0cea69>", line 4
#     *
#      ^
# SyntaxError: invalid syntax

# %%
X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")
# Out:
# *

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        11
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37
#
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_train)
print(confusion_matrix(y_train, pred_logreg))
print(classification_report(y_train, pred_logreg))
print(accuracy_score(y_train, pred_logreg))
# Out:
# [[60  0]
#  [ 0 24]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# 1.0

# %%
train_ml = train.copy()
test_ml = test.copy()

train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml.drop('Cheater',axis=1), train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

scaler.fit(train_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(train_ml.drop('Cheater',axis=1))
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns[:-1])

scaler.fit(test_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(test_ml.drop('Cheater',axis=1))
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns[:-1])

# %%
# unscaled
X_train_all = train_ml.drop('Cheater',axis=1)
y_train_all = train_ml['Cheater']
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml['Cheater']
X_test_all_sc = test_ml_sc

# %%
X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")
# Out:
# *

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [11  0]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.83        26
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.70        37
#    macro avg       0.35      0.50      0.41        37
# weighted avg       0.49      0.70      0.58        37
#
# 0.7027027027027027
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-6dcffa98c8ca> in <module>
#       1 logreg.fit(X_train_all, y_train_all)
# ----> 2 pred_all_logreg = logreg.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     305             Predicted class label per sample.
#     306         """
# --> 307         scores = self.decision_function(X)
#     308         if len(scores.shape) == 1:
#     309             indices = (scores > 0).astype(np.int)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
#     287                              % (X.shape[1], n_features))
#     288
#
# ValueError: X has 7 features per sample; expecting 6

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all.drop('Cheater',axis=1))

# %%
sub_logreg = pd.DataFrame()
sub_logreg = test
sub_logreg['Cheater'] = pred_all_logreg
#sub_logmodel.to_csv('logmodel.csv',index=False)
# Out:
# <ipython-input-53-107b57c570dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_logreg['Cheater'] = pred_all_logreg

# %%
sub_logreg = pd.DataFrame()
sub_logreg = test
sub_logreg.loc = pred_all_logreg
# Out:
# <ipython-input-54-9a378a412b48>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   sub_logreg.loc = pred_all_logreg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5169                 else:
# -> 5170                     object.__setattr__(self, name, value)
#    5171             except (AttributeError, TypeError):
#
# AttributeError: can't set attribute
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-9a378a412b48> in <module>
#       1 sub_logreg = pd.DataFrame()
#       2 sub_logreg = test
# ----> 3 sub_logreg.loc = pred_all_logreg
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5178                         stacklevel=2,
#    5179                     )
# -> 5180                 object.__setattr__(self, name, value)
#    5181
#    5182     def _dir_additions(self):
#
# AttributeError: can't set attribute

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
pred_gnb = gnb.predict(X_test)
print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[25  1]
#  [10  1]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.96      0.82        26
#            1       0.50      0.09      0.15        11
#
#     accuracy                           0.70        37
#    macro avg       0.61      0.53      0.49        37
# weighted avg       0.65      0.70      0.62        37
#
# 0.7027027027027027

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc,y_train_sc)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all.drop('Cheater',axis=1))

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [11  0]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.83        26
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.70        37
#    macro avg       0.35      0.50      0.41        37
# weighted avg       0.49      0.70      0.58        37
#
# 0.7027027027027027
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
pred_gnb = gnb.predict(X_test)
print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[25  1]
#  [10  1]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.96      0.82        26
#            1       0.50      0.09      0.15        11
#
#     accuracy                           0.70        37
#    macro avg       0.61      0.53      0.49        37
# weighted avg       0.65      0.70      0.62        37
#
# 0.7027027027027027

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-6dcffa98c8ca> in <module>
#       1 logreg.fit(X_train_all, y_train_all)
# ----> 2 pred_all_logreg = logreg.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     305             Predicted class label per sample.
#     306         """
# --> 307         scores = self.decision_function(X)
#     308         if len(scores.shape) == 1:
#     309             indices = (scores > 0).astype(np.int)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
#     287                              % (X.shape[1], n_features))
#     288
#
# ValueError: X has 7 features per sample; expecting 6

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-a05b65f41c1a> in <module>
#       2 logreg = LogisticRegression()
#       3 logreg.fit(X_train_all, y_train_all)
# ----> 4 pred_all_logreg = logreg.predict(X_test_all)
#       5 print(confusion_matrix(y_test, pred_logreg))
#       6 print(classification_report(y_test, pred_logreg))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     305             Predicted class label per sample.
#     306         """
# --> 307         scores = self.decision_function(X)
#     308         if len(scores.shape) == 1:
#     309             indices = (scores > 0).astype(np.int)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
#     287                              % (X.shape[1], n_features))
#     288
#
# ValueError: X has 7 features per sample; expecting 6

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml, test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml, test_size=0.30, random_state=101)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-d8196a1aa8bd> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(train_ml, test_size=0.30, random_state=101)
#       3 X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml, test_size=0.30, random_state=101)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml.drop('Cheater',axis=1), train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(train_ml)
scaled_features = scaler.transform(train_ml)
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns)

# %%
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml, train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
corr = train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# for train_ml
scaler.fit(train_ml)
scaled_features = scaler.transform(train_ml)
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns)

# for test_ml
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml, train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

# %%
# unscaled
X_train_all = train_ml.drop('Cheater',axis=1)
y_train_all = train_ml['Cheater']
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml['Cheater']
X_test_all_sc = test_ml_sc

# %%
X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")
# Out:
# *

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        11
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37
#
# 1.0

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml, train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# for train_ml
scaler.fit(train_ml)
scaled_features = scaler.transform(train_ml)
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns)

# for test_ml
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)

# %%
# unscaled
X_train_all = train_ml.drop('Cheater',axis=1)
y_train_all = train_ml['Cheater']
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml['Cheater']
X_test_all_sc = test_ml_sc

# %%
X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")
# Out:
# *

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        11
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37
#
# 1.0

# %%
train_ml = train.copy()
test_ml = test.copy()

train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_ml.drop('Cheater',axis=1), train_ml['Cheater'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(train_ml_sc, train_ml['Cheater'], test_size=0.30, random_state=101)

scaler.fit(train_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(train_ml.drop('Cheater',axis=1))
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns[:-1])

scaler.fit(test_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(test_ml.drop('Cheater',axis=1))
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns[:-1])



# unscaled
X_train_all = train_ml.drop('Cheater',axis=1)
y_train_all = train_ml['Cheater']
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml['Cheater']
X_test_all_sc = test_ml_sc




X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")



from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))


logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all.drop('Cheater',axis=1))
# Out:
# *
# [[26  0]
#  [11  0]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.83        26
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.70        37
#    macro avg       0.35      0.50      0.41        37
# weighted avg       0.49      0.70      0.58        37
#
# 0.7027027027027027
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# for train_ml
scaler.fit(train_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(train_ml.drop('Cheater',axis=1))
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns[:-1])

# for test_ml
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaler.fit(test_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(test_ml.drop('Cheater',axis=1))
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns[:-1])

# %%
X_train_all = train_ml.drop('Cheater',axis=1)
y_train_all = train_ml['Cheater']
X_test_all = test_ml

# scaled
X_train_all_sc = train_ml_sc
y_train_all_sc = train_ml['Cheater']
X_test_all_sc = test_ml_sc

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [11  0]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.83        26
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.70        37
#    macro avg       0.35      0.50      0.41        37
# weighted avg       0.49      0.70      0.58        37
#
# 0.7027027027027027
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all.drop('Cheater',axis=1))

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
pred_gnb = gnb.predict(X_test)
print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[25  1]
#  [10  1]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.96      0.82        26
#            1       0.50      0.09      0.15        11
#
#     accuracy                           0.70        37
#    macro avg       0.61      0.53      0.49        37
# weighted avg       0.65      0.70      0.62        37
#
# 0.7027027027027027

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc,y_train_sc)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[26  0]
#  [11  0]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.83        26
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.70        37
#    macro avg       0.35      0.50      0.41        37
# weighted avg       0.49      0.70      0.58        37
#
# 0.7027027027027027
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-6dcffa98c8ca> in <module>
#       1 logreg.fit(X_train_all, y_train_all)
# ----> 2 pred_all_logreg = logreg.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     305             Predicted class label per sample.
#     306         """
# --> 307         scores = self.decision_function(X)
#     308         if len(scores.shape) == 1:
#     309             indices = (scores > 0).astype(np.int)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
#     287                              % (X.shape[1], n_features))
#     288
#
# ValueError: X has 7 features per sample; expecting 6

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all.drop('Cheater',axis=1))

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
pred_gnb = gnb.predict(X_test)
print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[25  1]
#  [10  1]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.96      0.82        26
#            1       0.50      0.09      0.15        11
#
#     accuracy                           0.70        37
#    macro avg       0.61      0.53      0.49        37
# weighted avg       0.65      0.70      0.62        37
#
# 0.7027027027027027

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc,y_train_sc)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc,y_train_sc)
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-54b4fe335a4d> in <module>
#       2 knn = KNeighborsClassifier(n_neighbors=20)
#       3 knn.fit(X_train_sc,y_train_sc)
# ----> 4 pred_knn = knn.predict(X_test)
#       5 print(confusion_matrix(y_test, pred_knn))
#       6 print(classification_report(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
pred_gnb = gnb.predict(X_test)
print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[25  1]
#  [10  1]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.96      0.82        26
#            1       0.50      0.09      0.15        11
#
#     accuracy                           0.70        37
#    macro avg       0.61      0.53      0.49        37
# weighted avg       0.65      0.70      0.62        37
#
# 0.7027027027027027

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc,y_train_sc)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
pred.fit(X_train_sc,y_train_sc)
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-e2b083a05ce5> in <module>
# ----> 1 pred.fit(X_train_sc,y_train_sc)
#       2 pred_knn = knn.predict(X_test)
#       3 print(confusion_matrix(y_test, pred_knn))
#       4 print(classification_report(y_test, pred_knn))
#       5 print(accuracy_score(y_test, pred_knn))
#
# NameError: name 'pred' is not defined

# %%
knn.fit(X_train_sc,y_train_sc)
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-e03af0af0925> in <module>
#       1 knn.fit(X_train_sc,y_train_sc)
# ----> 2 pred_knn = knn.predict(X_test)
#       3 print(confusion_matrix(y_test, pred_knn))
#       4 print(classification_report(y_test, pred_knn))
#       5 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
from sklearn import *
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-a2af48fbc06c> in <module>
#       1 from sklearn import *
#       2 logreg.fit(X_train_all, y_train_all)
# ----> 3 pred_all_logreg = logreg.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     305             Predicted class label per sample.
#     306         """
# --> 307         scores = self.decision_function(X)
#     308         if len(scores.shape) == 1:
#     309             indices = (scores > 0).astype(np.int)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
#     287                              % (X.shape[1], n_features))
#     288
#
# ValueError: X has 7 features per sample; expecting 6

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
pred_gnb = gnb.predict(X_test)
print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[25  1]
#  [10  1]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.96      0.82        26
#            1       0.50      0.09      0.15        11
#
#     accuracy                           0.70        37
#    macro avg       0.61      0.53      0.49        37
# weighted avg       0.65      0.70      0.62        37
#
# 0.7027027027027027

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc,y_train_sc)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-7b8fd0e45bf1> in <module>
# ----> 1 pred_knn = knn.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_knn))
#       3 print(classification_report(y_test, pred_knn))
#       4 print(accuracy_score(y_test, pred_knn))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
knn.fit(X_train_all, y_train_all)
pred_all_knn = knn.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-ab1f5bfa936e> in <module>
#       1 knn.fit(X_train_all, y_train_all)
# ----> 2 pred_all_knn = knn.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     173         X = check_array(X, accept_sparse='csr')
#     174
# --> 175         neigh_dist, neigh_ind = self.kneighbors(X)
#     176         classes_ = self.classes_
#     177         _y = self._y
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtree = dtree.predict(X_test)
print(classification_report(y_test,pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.65      0.67        26
#            1       0.25      0.27      0.26        11
#
#     accuracy                           0.54        37
#    macro avg       0.47      0.46      0.46        37
# weighted avg       0.55      0.54      0.55        37
#
# 0.5405405405405406

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-38d1b467f853> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2.fit(X_train_all, y_train_all)
pred_all_dtree2 = dtree_2.predict(X_test_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-00cea9fe2d7d> in <module>
# ----> 1 dtree_2.fit(X_train_all, y_train_all)
#       2 pred_all_dtree2 = dtree_2.predict(X_test_all)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth=6, max_features=7)
rfc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-5e71d2903f15> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 rfc = RandomForestClassifier(max_depth=6, max_features=7)
# ----> 3 rfc.fit(X_train, y_train)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
pred_rfc = rfc.predict(X_test)
print(confusion_matrix(y_test, pred_rfc))
print(classification_report(y_test, pred_rfc))
print(accuracy_score(y_test, pred_rfc))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-124-4266af497852> in <module>
# ----> 1 pred_rfc = rfc.predict(X_test)
#       2 print(confusion_matrix(y_test, pred_rfc))
#       3 print(classification_report(y_test, pred_rfc))
#       4 print(accuracy_score(y_test, pred_rfc))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# IndexError: list index out of range

# %%
rom sklearn.svm import SVC
svc = SVC(gamma = 0.01, C = 100)#, probability=True)
svc.fit(X_train_sc, y_train_sc)
# Out:
#   File "<ipython-input-125-9f2c0344f858>", line 1
#     rom sklearn.svm import SVC
#         ^
# SyntaxError: invalid syntax

# %%
from sklearn.svm import SVC
svc = SVC(gamma = 0.01, C = 100)#, probability=True)
svc.fit(X_train_sc, y_train_sc)
# Out:
# SVC(C=100, gamma=0.01)

# %%
pred_svc = svc.predict(X_test_sc)
print(confusion_matrix(y_test_sc, pred_svc))
print(classification_report(y_test_sc, pred_svc))
print(accuracy_score(y_test_sc, pred_svc))
# Out:
# [[26  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        11
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37
#
# 1.0

# %%
from sklearn.model_selection import cross_val_score

# %%
scores_svc = cross_val_score(svc, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_svc)
print(scores_svc.mean())
# Out:
# [0.69230769 0.66666667 0.66666667 0.66666667 0.66666667 0.75
#  0.66666667 0.75       0.75       0.75      ]
# 0.7025641025641025

# %%
scores_rfc = cross_val_score(rfc, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_rfc)
print(scores_rfc.mean())
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [nan nan nan nan nan nan nan nan nan nan]
# nan
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 386, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 866, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 784, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %%
ll_sc, cv=10, scoring='accuracy')
print(scores_dtree_2)
print(scores_dtree_2.mean())
# Out:
#   File "<ipython-input-131-c2562bb7d38f>", line 1
#     ll_sc, cv=10, scoring='accuracy')
#                                     ^
# SyntaxError: unmatched ')'

# %%
scores_dtree_2 = cross_val_score(dtree_2, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_dtree_2)
print(scores_dtree_2.mean())
# Out:
# [nan nan nan nan nan nan nan nan nan nan]
# nan
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 890, in fit
#     super().fit(
#   File "/Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %%
print("dtree_2 : " , scores_dtree_2.mean())
print("rfc     : " , scores_rfc.mean())
print("svc     : " , scores_svc.mean())
# Out:
# dtree_2 :  nan
# rfc     :  nan
# svc     :  0.7025641025641025

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-38d1b467f853> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtree = dtree.predict(X_test)
print(classification_report(y_test,pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77        26
#            1       0.45      0.45      0.45        11
#
#     accuracy                           0.68        37
#    macro avg       0.61      0.61      0.61        37
# weighted avg       0.68      0.68      0.68        37
#
# 0.6756756756756757

# %%
pred_dtree = dtree.predict(X_train)
print(classification_report(y_test,pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-b9d70a1aa562> in <module>
#       1 pred_dtree = dtree.predict(X_train)
# ----> 2 print(classification_report(y_test,pred_dtree))
#       3 print(accuracy_score(y_test, pred_dtree))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1927     """
#    1928
# -> 1929     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1930
#    1931     labels_given = True
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      79     y_pred : array or indicator matrix
#      80     """
# ---> 81     check_consistent_length(y_true, y_pred)
#      82     type_true = type_of_target(y_true)
#      83     type_pred = type_of_target(y_pred)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [37, 84]

# %%
pred_dtree = dtree.predict(X_train)
print(classification_report(y_train,pred_dtree))
print(accuracy_score(y_train, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# 1.0

# %%
pred_dtree = dtree.predict(X_test)
print(classification_report(y_test,pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77        26
#            1       0.45      0.45      0.45        11
#
#     accuracy                           0.68        37
#    macro avg       0.61      0.61      0.61        37
# weighted avg       0.68      0.68      0.68        37
#
# 0.6756756756756757

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-38d1b467f853> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features=8 , max_depth=7,  min_samples_split=9)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-268915a7c2f3> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=8 , max_depth=7,  min_samples_split=9)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features=7, max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-2fff8cee4d10> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7, max_depth=6,  min_samples_split=8)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features=None, max_depth=None,  min_samples_split=None)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-f31c22d491e6> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=None, max_depth=None,  min_samples_split=None)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     232             min_samples_split = self.min_samples_split
#     233         else:  # float
# --> 234             if not 0. < self.min_samples_split <= 1.:
#     235                 raise ValueError("min_samples_split must be an integer "
#     236                                  "greater than 1 or a float in (0.0, 1.0]; "
#
# TypeError: '<' not supported between instances of 'float' and 'NoneType'

# %%
dtree_2 = DecisionTreeClassifier(max_features=max_features * n_features, max_depth=None,  min_samples_split=None)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-7ca77e554ebb> in <module>
# ----> 1 dtree_2 = DecisionTreeClassifier(max_features=max_features * n_features, max_depth=None,  min_samples_split=None)
#       2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# NameError: name 'max_features' is not defined

# %%
dtree_2 = DecisionTreeClassifier(max_features=sqrt(n_features), max_depth=None,  min_samples_split=None)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-0164dcbafdab> in <module>
# ----> 1 dtree_2 = DecisionTreeClassifier(max_features=sqrt(n_features), max_depth=None,  min_samples_split=None)
#       2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# NameError: name 'sqrt' is not defined

# %%
dtree_2 = DecisionTreeClassifier(max_features=Auto, max_depth=None,  min_samples_split=None)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-b70e063da165> in <module>
# ----> 1 dtree_2 = DecisionTreeClassifier(max_features=Auto, max_depth=None,  min_samples_split=None)
#       2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# NameError: name 'Auto' is not defined

# %%
dtree_2 = DecisionTreeClassifier(max_features=auto, max_depth=None,  min_samples_split=None)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-ff2901b52352> in <module>
# ----> 1 dtree_2 = DecisionTreeClassifier(max_features=auto, max_depth=None,  min_samples_split=None)
#       2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# NameError: name 'auto' is not defined

# %%
dtree_2 = DecisionTreeClassifier(max_features=float, max_depth=None,  min_samples_split=None)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-824d69c3ec7f> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=float, max_depth=None,  min_samples_split=None)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     232             min_samples_split = self.min_samples_split
#     233         else:  # float
# --> 234             if not 0. < self.min_samples_split <= 1.:
#     235                 raise ValueError("min_samples_split must be an integer "
#     236                                  "greater than 1 or a float in (0.0, 1.0]; "
#
# TypeError: '<' not supported between instances of 'float' and 'NoneType'

# %%
dtree_2 = DecisionTreeClassifier(max_features=float, max_depth=float,  min_samples_split=float)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-2b18b213b0a1> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=float, max_depth=float,  min_samples_split=float)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     232             min_samples_split = self.min_samples_split
#     233         else:  # float
# --> 234             if not 0. < self.min_samples_split <= 1.:
#     235                 raise ValueError("min_samples_split must be an integer "
#     236                                  "greater than 1 or a float in (0.0, 1.0]; "
#
# TypeError: '<' not supported between instances of 'float' and 'type'

# %%
dtree_2 = DecisionTreeClassifier(max_features=10, max_depth=8,  min_samples_split=9)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-651da5865af4> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=10, max_depth=8,  min_samples_split=9)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
dtree_2 = DecisionTreeClassifier(max_features=10, n_features, max_depth=8,  min_samples_split=9)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
#   File "<ipython-input-151-08931f273dea>", line 1
#     dtree_2 = DecisionTreeClassifier(max_features=10, n_features, max_depth=8,  min_samples_split=9)
#                                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , n_features, max_depth=5,  min_samples_split=6)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
#   File "<ipython-input-152-7402f71c8474>", line 1
#     dtree_2 = DecisionTreeClassifier(max_features=7 , n_features, max_depth=5,  min_samples_split=6)
#                                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=5,  min_samples_split=6)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-b767e4166301> in <module>
#       1 dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=5,  min_samples_split=6)
# ----> 2 dtree_2.fit(X_train,y_train)
#       3 pred_dtree_2 = dtree_2.predict(X_test)
#       4 print(classification_report(y_test, pred_dtree_2))
#       5 print(accuracy_score(y_test, pred_dtree_2))
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     277             raise ValueError("max_depth must be greater than zero. ")
#     278         if not (0 < max_features <= self.n_features_):
# --> 279             raise ValueError("max_features must be in (0, n_features]")
#     280         if not isinstance(max_leaf_nodes, numbers.Integral):
#     281             raise ValueError("max_leaf_nodes must be integral number but was "
#
# ValueError: max_features must be in (0, n_features]

# %%
df_train_ml = df_train.copy()
df_test_ml = df_test.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-8f05eadd74cf> in <module>
# ----> 1 df_train_ml = df_train.copy()
#       2 df_test_ml = df_test.copy()
#
# NameError: name 'df_train' is not defined

# %%
train_ml = train.copy()
test_ml = test.copy()

# %%
train_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 1 to 169
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SexDimorph  121 non-null    float64
#  1   Attract     121 non-null    float64
#  2   Cheater     121 non-null    int64
#  3   Trust       121 non-null    float64
#  4   Faithful    121 non-null    float64
#  5   FaceSex     121 non-null    object
#  6   RaterSex    121 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 7.6+ KB

# %%
train.head()
# Out:
#    SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 1       4.900    2.000        1  4.118     6.294       F        M
# 4       4.083    2.917        0  4.118     5.412       F        M
# 6       2.000    1.833        0  4.647     6.647       F        M
# 7       2.273    1.417        1  3.588     6.235       F        M
# 8       3.917    2.417        1  4.118     4.600       F        M

# %%
test.head()
# Out:
#     SexDimorph  Attract  Cheater  Trust  Faithful FaceSex RaterSex
# 2        2.583    2.083        0  4.000     6.588       F        M
# 3        4.300    2.667        0  3.941     5.824       F        M
# 5        4.500    3.500        0  3.235     4.000       F        M
# 9        5.833    4.417        0  3.235     3.550       F        M
# 15       2.333    1.833        0  4.765     6.706       F        M

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 1 to 169
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SexDimorph  121 non-null    float64
#  1   Attract     121 non-null    float64
#  2   Cheater     121 non-null    int64
#  3   Trust       121 non-null    float64
#  4   Faithful    121 non-null    float64
#  5   FaceSex     121 non-null    object
#  6   RaterSex    121 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 7.6+ KB

# %%
sns.countplot(x='Cheater', data=train);

# %%
sns.countplot(x='Cheater', data=train['Faithful']);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-5c1403fc5838> in <module>
# ----> 1 sns.countplot(x='Cheater', data=train['Faithful']);
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3583         raise ValueError("Cannot pass values for both `x` and `y`")
#    3584
# -> 3585     plotter = _CountPlotter(
#    3586         x, y, hue, data, order, hue_order,
#    3587         estimator, ci, n_boot, units, seed,
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Cheater'

# %%
train.groupby(['Cheater','Sex'])['Cheater'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-6043aee30799> in <module>
# ----> 1 train.groupby(['Cheater','Sex'])['Cheater'].count()
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'Sex'

# %%
train.groupby(['Cheater','FaceSex'])['Cheater'].count()
# Out:
# Cheater  FaceSex
# 0        F          45
#          M          41
# 1        F          18
#          M          17
# Name: Cheater, dtype: int64

# %%
sns.catplot(x='FaceSex', col='Cheater', kind='count', data=train);

# %%
print("% of women cheaters: " , train[train.FaceSex == 'female'].Cheater.sum()/train[train.FaceSex == 'female'].Cheater.count())
print("% of men cheaters:   " , train[train.FaceSex == 'male'].Cheater.sum()/train[train.FaceSex == 'male'].Cheater.count())
# Out:
# % of women cheaters:  nan
# % of men cheaters:    nan
# <ipython-input-166-8b8e3549d699>:1: RuntimeWarning: invalid value encountered in long_scalars
#   print("% of women cheaters: " , train[train.FaceSex == 'female'].Cheater.sum()/train[train.FaceSex == 'female'].Cheater.count())
# <ipython-input-166-8b8e3549d699>:2: RuntimeWarning: invalid value encountered in long_scalars
#   print("% of men cheaters:   " , train[train.FaceSex == 'male'].Cheater.sum()/train[train.FaceSex == 'male'].Cheater.count())

# %%
print("% of women cheaters: " , train[train.FaceSex == 'F'].Cheater.sum()/train[train.FaceSex == 'F'].Cheater.count())
print("% of men cheaters:   " , train[train.FaceSex == 'M'].Cheater.sum()/train[train.FaceSex == 'M'].Cheater.count())
# Out:
# % of women cheaters:  0.2857142857142857
# % of men cheaters:    0.29310344827586204

# %%
f,ax=plt.subplots(1,2,figsize=(16,7))
train['Cheater'][train['FaceSex']=='M'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
train['Cheater'][train['FaceSex']=='F'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
ax[0].set_title('Cheater (male)')
ax[1].set_title('Cheater (female)')

plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# for train_ml
scaler.fit(train_ml.drop('Cheater',axis=1))
scaled_features = scaler.transform(train_ml.drop('Cheater',axis=1))
train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns[:-1])

# for test_ml
test_ml.fillna(test_ml.mean(), inplace=True)
# scaler.fit(test_ml)
scaled_features = scaler.transform(test_ml)
test_ml_sc = pd.DataFrame(scaled_features, columns=test_ml.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-60896f0568e4> in <module>
#       3
#       4 # for train_ml
# ----> 5 scaler.fit(train_ml.drop('Cheater',axis=1))
#       6 scaled_features = scaler.transform(train_ml.drop('Cheater',axis=1))
#       7 train_ml_sc = pd.DataFrame(scaled_features, columns=train_ml.columns[:-1])
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     694             Transformer instance.
#     695         """
# --> 696         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     697                                 estimator=self, dtype=FLOAT_DTYPES,
#     698                                 force_all_finite='allow-nan')
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# /Applications/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# /Applications/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'F'

# %%
train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
train_ml.dropna(inplace=True)

# %%
test_ml = pd.get_dummies(df_test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
test_ml.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-171-ebaeeb49bb20> in <module>
# ----> 1 test_ml = pd.get_dummies(df_test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
#       2 test_ml.dropna(inplace=True)
#
# NameError: name 'df_test_ml' is not defined

# %%
train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
train_ml.dropna(inplace=True)


test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
test_ml.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-376e29fda993> in <module>
# ----> 1 train_ml = pd.get_dummies(train_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
#       2 train_ml.dropna(inplace=True)
#       3
#       4
#       5 test_ml = pd.get_dummies(test_ml, columns=['FaceSex', 'RaterSex'], drop_first=True)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     841             raise TypeError("Input must be a list-like for parameter `columns`")
#     842         else:
# --> 843             data_to_encode = data[columns]
#     844
#     845         # validate prefixes and separator to avoid silently dropping cols
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['FaceSex', 'RaterSex'], dtype='object')] are in the [columns]"
